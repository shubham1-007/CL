# %%
import pandas as pd
df=pd.read_csv('Car_Evaluation.csv')

df.head()
# Out:
#    vhigh vhigh.1  2 2.1  small   low  unacc
# 0  vhigh   vhigh  2   2  small   med  unacc
# 1  vhigh   vhigh  2   2  small  high  unacc
# 2  vhigh   vhigh  2   2    med   low  unacc
# 3  vhigh   vhigh  2   2    med   med  unacc
# 4  vhigh   vhigh  2   2    med  high  unacc

# %%
columns=['Buying','maint','doors','persons','lug_boot','safety','class']
df.columns=columns
df.head()
# Out:
#   Buying  maint doors persons lug_boot safety  class
# 0  vhigh  vhigh     2       2    small    med  unacc
# 1  vhigh  vhigh     2       2    small   high  unacc
# 2  vhigh  vhigh     2       2      med    low  unacc
# 3  vhigh  vhigh     2       2      med    med  unacc
# 4  vhigh  vhigh     2       2      med   high  unacc

# %%
df_mod=pd.get_dummies(data=df,columns=columns[:-1],drop_first=True)
df_mod.head()
# Out:
#    class  Buying_low  Buying_med  Buying_vhigh  maint_low  maint_med
# 0  unacc       False       False          True      False      False  \
# 1  unacc       False       False          True      False      False
# 2  unacc       False       False          True      False      False
# 3  unacc       False       False          True      False      False
# 4  unacc       False       False          True      False      False
#
#    maint_vhigh  doors_3  doors_4  doors_5more  persons_4  persons_more
# 0         True    False    False        False      False         False  \
# 1         True    False    False        False      False         False
# 2         True    False    False        False      False         False
# 3         True    False    False        False      False         False
# 4         True    False    False        False      False         False
#
#    lug_boot_med  lug_boot_small  safety_low  safety_med
# 0         False            True       False        True
# 1         False            True       False       False
# 2          True           False        True       False
# 3          True           False       False        True
# 4          True           False       False       False

# %%
X=df_mod.drop('class',axis=1)
y=df_mod['class']
X.head()
# Out:
#    Buying_low  Buying_med  Buying_vhigh  maint_low  maint_med  maint_vhigh
# 0       False       False          True      False      False         True  \
# 1       False       False          True      False      False         True
# 2       False       False          True      False      False         True
# 3       False       False          True      False      False         True
# 4       False       False          True      False      False         True
#
#    doors_3  doors_4  doors_5more  persons_4  persons_more  lug_boot_med
# 0    False    False        False      False         False         False  \
# 1    False    False        False      False         False         False
# 2    False    False        False      False         False          True
# 3    False    False        False      False         False          True
# 4    False    False        False      False         False          True
#
#    lug_boot_small  safety_low  safety_med
# 0            True       False        True
# 1            True       False       False
# 2           False        True       False
# 3           False       False        True
# 4           False       False       False

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y)

# %%
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier(random_state=42)

# %%
clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
from sklearn.metrics import accuracy_score, classification_report
y_pred=clf.predict(x_test)
accuracy=accuracy_score(y_pred,y_test)
print(f'accuracy is {accuracy*100:.2f}%')
report=classification_report(y_pred,y_test,target_names=df_mod['class'].unique())
print(report)
# Out:
# accuracy is 89.81%
#               precision    recall  f1-score   support
#
#        unacc       0.82      0.80      0.81       106
#          acc       0.20      0.67      0.31         6
#        vgood       0.99      0.94      0.96       312
#         good       0.54      0.88      0.67         8
#
#     accuracy                           0.90       432
#    macro avg       0.64      0.82      0.69       432
# weighted avg       0.93      0.90      0.91       432
